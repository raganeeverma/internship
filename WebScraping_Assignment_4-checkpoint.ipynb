# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

import warnings
warnings.filterwarnings("ignore")

from selenium.webdriver.common.by  import By

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
# first connect to the driver

driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# connect to  the url that i want to open 
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")
time.sleep(3)

# %%
Rank=[]
Name=[]
Artist=[]
Upload_Date=[]
Views=[]

# %%
#Scraping data of rank details
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[0:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
#Scraping data of video names
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

# %%
#Scraping data of artist name
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')

# %%
#Scraping data of views
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
#Scraping data of upload dates
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
        Upload_Date.append(i.text)
except NoSuchElementException:        
    Upload_Date.append('-')

# %%
#framing of scraped data 

Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_Date
Youtube['Views'] = Views

# %%
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                                  "Bath Song"[15]
# 5    6.                              "See You Again"[16]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                                     "Axel F"[36]
# 18  18.                          "Thinking Out Loud"[37]
# 19  20.                        "Baa Baa Black Sheep"[38]
# 20  21.                                 "Dark Horse"[39]
# 21  22.                                      "Faded"[40]
# 22  23.                             "Girls Like You"[41]
# 23  24.                                 "Let Her Go"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Perfect"[44]
# 26  27.                                    "Lean On"[45]
# 27  28.           "Waka Waka (This Time for Africa)"[46]
# 28  29.                               "Shake It Off"[47]
# 29  30.          "Humpty the train on a fruits ride"[48]
#
#                                            Artist      Uploaded Date  Views
# 0     Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  11.58
# 1                                      Luis Fonsi   January 12, 2017   7.99
# 2                                     LooLoo Kids    October 8, 2016   6.50
# 3                                      Ed Sheeran   January 30, 2017   5.83
# 4                      Cocomelon – Nursery Rhymes        May 2, 2018   5.68
# 5                                     Wiz Khalifa      April 6, 2015   5.68
# 6                                       ChuChu TV      March 6, 2014   4.96
# 7                                     Mark Ronson  November 19, 2014   4.73
# 8                                     Miroshka TV  February 27, 2018   4.69
# 9                                             Psy      July 15, 2012   4.58
# 10                                     Get Movies   January 31, 2012   4.51
# 11                     Cocomelon – Nursery Rhymes       May 24, 2018   4.50
# 12                                      El Chombo      April 5, 2018   4.11
# 13                                       Maroon 5   January 14, 2015   3.77
# 14                                     Katy Perry  September 5, 2013   3.67
# 15                                    OneRepublic       May 31, 2013   3.67
# 16                                  Justin Bieber   October 22, 2015   3.60
# 17                                     Crazy Frog      June 16, 2009   3.56
# 18                                     Ed Sheeran    October 7, 2014   3.51
# 19                     Cocomelon – Nursery Rhymes      June 25, 2018   3.41
# 20                                     Katy Perry  February 20, 2014   3.37
# 21                                    Alan Walker   December 3, 2015   3.36
# 22                                       Maroon 5       May 31, 2018   3.34
# 23                                      Passenger      July 25, 2012   3.32
# 24                               Enrique Iglesias     April 11, 2014   3.29
# 25                                     Ed Sheeran   November 9, 2017   3.28
# 26                                    Major Lazer     March 22, 2015   3.28
# 27                                        Shakira       June 4, 2010   3.27
# 28                                   Taylor Swift    August 18, 2014   3.22
# 29  Kiddiestv Hindi – Nursery Rhymes & Kids Songs   January 26, 2018   3.19

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
# first connect to the driver

driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# connect to  the url that i want to open 

driver.get("https://www.guru99.com/")
time.sleep(3)

# %%
#Going to search bar and searching for selenium exception

serch_btn = driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
serch_btn.send_keys("selenium exception handling")

# %%
serch_btn = driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button").click()
time.sleep(3)

# %%
#Url of selenium exception handling page

urls = driver.find_element(By.XPATH,"//div[@class='gsc-expansionArea']//div//a")
page_url = urls.get_attribute("href")

driver.get(page_url)
time.sleep(5)

# %%
Name = []
Description = []

for i in driver.find_elements(By.XPATH ,'//div[@class="entry-content-wrap"]/div/p')[:41]:
    
    k = i.text.split(':')
    Name.append(k[0][2:].strip('.'))


# #Scraping data of descriptions of exceptions  
    Description.append(k[1])
    
#DATA FRAMEING
Guru=pd.DataFrame({})
Guru['Name of Exception'] = Name
Guru['Description of Exception'] = Description

#Printing data frame
Guru
# Out:
#                        Name of Exception  \
# 0             ElementNotVisibleException
# 1          ElementNotSelectableException
# 2                 NoSuchElementException
# 3                   NoSuchFrameException
# 4                NoAlertPresentException
# 5                  NoSuchWindowException
# 6         StaleElementReferenceException
# 7               SessionNotFoundException
# 8                       TimeoutException
# 9                     WebDriverException
# 10             ConnectionClosedException
# 11      ElementClickInterceptedException
# 12       ElementNotInteractableException
# 13              ErrorInResponseException
# 14   ErrorHandler.UnknownServerException
# 15          ImeActivationFailedException
# 16              ImeNotAvailableException
# 17          InsecureCertificateException
# 18              InvalidArgumentException
# 19          InvalidCookieDomainException
# 20           InvalidCoordinatesException
# 21          InvalidElementStateException
# 22             InvalidSessionIdException
# 23        InvalidSwitchToTargetException
# 24                   JavascriptException
# 25                         JsonException
# 26              NoSuchAttributeException
# 27        MoveTargetOutOfBoundsException
# 28                NoSuchContextException
# 29                 NoSuchCookieException
# 30                     NotFoundException
# 31           RemoteDriverServerException
# 32                   ScreenshotException
# 33            SessionNotCreatedException
# 34            UnableToSetCookieException
# 35            UnexpectedTagNameException
# 36               UnhandledAlertException
# 37       UnexpectedAlertPresentException
# 38                UnknownMethodException
# 39           UnreachableBrowserException
# 40           UnsupportedCommandException
#
#                              Description of Exception
# 0    This type of Selenium exception occurs when a...
# 1    This Selenium exception occurs when an elemen...
# 2    This Exception occurs if an element could not...
# 3    This Exception occurs if the frame target to ...
# 4    This Exception occurs when you switch to no p...
# 5    This Exception occurs if the window target to...
# 6    This Selenium exception occurs happens when t...
# 7    The WebDriver is acting after you quit the br...
# 8    Thrown when there is not enough time for a co...
# 9    This Exception takes place when the WebDriver...
# 10   This type of Exception takes place when there...
# 11   The command may not be completed as the eleme...
# 12   This Selenium exception is thrown when any el...
# 13   This happens while interacting with the Firef...
# 14   Exception is used as a placeholder in case if...
# 15   This expectation will occur when IME engine a...
# 16    It takes place when IME support is unavailable.
# 17   Navigation made the user agent to hit a certi...
# 18   It occurs when an argument does not belong to...
# 19   This happens when you try to add a cookie und...
# 20   This type of Exception matches an interacting...
# 21   It occurs when command can’t be finished when...
# 22   This Exception took place when the given sess...
# 23   This occurs when the frame or window target t...
# 24   This issue occurs while executing JavaScript ...
# 25   It occurs when you afford to get the session ...
# 26   This kind of Exception occurs when the attrib...
# 27   It takes place if the target provided to the ...
# 28           ContextAware does mobile device testing.
# 29   This Exception occurs when no cookie matching...
# 30   This Exception is a subclass of WebDriverExce...
# 31   This Selenium exception is thrown when the se...
# 32            It is not possible to capture a screen.
# 33   It happens when a new session could not be su...
# 34   This occurs if a driver is unable to set a co...
# 35   Happens if a support class did not get a web ...
# 36   This expectation occurs when there is an aler...
# 37   It occurs when there is the appearance of an ...
# 38   This Exception happens when the requested com...
# 39   This Exception occurs only when the browser i...
# 40   This occurs when remote WebDriver doesn’t sen...

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# first connect to the driver

driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# connect to  the url that i want to open 

driver.get("http://statisticstimes.com/")
time.sleep(3)

# %%
#Clicking on economy section
economy = driver.find_element(By.XPATH ,"//div[@class='navbar']//div[2]//button").click()

urls = driver.find_element(By.XPATH ,"//div[@class='dropdown-content']//a[3]")
ineco_page = urls.get_attribute("href")
#Going to indian economy page
driver.get(ineco_page)  
time.sleep(5)

# %%
#Creating empty list
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
#get the url of page containing GDP of indian states
sta_GDP = driver.find_element(By.XPATH ,"//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
GDP_url = sta_GDP.get_attribute("href")

driver.get(GDP_url)
time.sleep(6)


#Scraping data of rank
for i in driver.find_elements(By.XPATH ,"//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
    Rank.append(i.text)

    
#Scraping data of state name
for i in driver.find_elements(By.XPATH ,"//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
    State.append(i.text)

    
# Scraping data of GSDP at current price (19-20)
for i in driver.find_elements(By.XPATH ,"//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
    GSDP_1.append(i.text)

    
#Scraping data of GSDP at current price (18-19)
for i in driver.find_elements(By.XPATH ,"//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
    GSDP_2.append(i.text)
    
#Scraping data of Share(18-19)
for i in driver.find_elements(By.XPATH ,"//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
    Share.append(i.text)

    
#Scraping data of GDP($ billion)
for i in driver.find_elements(By.XPATH ,"//div[@id='table_id_wrapper']//tbody//tr//td[6]"):
    GDP.append(i.text)

# %%
#DATA FRAMEING
StatisticsTime=pd.DataFrame({})
StatisticsTime['Rank'] = Rank
StatisticsTime['State'] = State
StatisticsTime['GSDP at current price (19-20)'] = GSDP_1
StatisticsTime['GSDP at current price (18-19)'] = GSDP_2
StatisticsTime['Share(18-19)'] = Share
StatisticsTime['GDP($ billion)'] = GDP

#Printing the data frame
StatisticsTime
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# 5     6                West Bengal                     1,253,832
# 6     7                  Rajasthan                     1,020,989
# 7     8             Andhra Pradesh                       972,782
# 8     9                  Telangana                       969,604
# 9    10             Madhya Pradesh                       906,672
# 10   11                     Kerala                             -
# 11   12                      Delhi                       856,112
# 12   13                    Haryana                       831,610
# 13   14                      Bihar                       611,804
# 14   15                     Punjab                       574,760
# 15   16                     Odisha                       521,275
# 16   17                      Assam                             -
# 17   18               Chhattisgarh                       329,180
# 18   19                  Jharkhand                       328,598
# 19   20                Uttarakhand                             -
# 20   21            Jammu & Kashmir                             -
# 21   22           Himachal Pradesh                       165,472
# 22   23                        Goa                        80,449
# 23   24                    Tripura                        55,984
# 24   25                 Chandigarh                             -
# 25   26                 Puducherry                        38,253
# 26   27                  Meghalaya                        36,572
# 27   28                     Sikkim                        32,496
# 28   29                    Manipur                        31,790
# 29   30                   Nagaland                             -
# 30   31          Arunachal Pradesh                             -
# 31   32                    Mizoram                        26,503
# 32   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share(18-19) GDP($ billion)
# 0                      2,632,792       13.94%        399.921
# 1                      1,630,208        8.63%        247.629
# 2                      1,584,764        8.39%        240.726
# 3                      1,502,899        7.96%        228.290
# 4                      1,493,127        7.91%        226.806
# 5                      1,089,898        5.77%        165.556
# 6                        942,586        4.99%        143.179
# 7                        862,957        4.57%        131.083
# 8                        861,031        4.56%        130.791
# 9                        809,592        4.29%        122.977
# 10                       781,653        4.14%        118.733
# 11                       774,870        4.10%        117.703
# 12                       734,163        3.89%        111.519
# 13                       530,363        2.81%         80.562
# 14                       526,376        2.79%         79.957
# 15                       487,805        2.58%         74.098
# 16                       315,881        1.67%         47.982
# 17                       304,063        1.61%         46.187
# 18                       297,204        1.57%         45.145
# 19                       245,895        1.30%         37.351
# 20                       155,956        0.83%         23.690
# 21                       153,845        0.81%         23.369
# 22                        73,170        0.39%         11.115
# 23                        49,845        0.26%          7.571
# 24                        42,114        0.22%          6.397
# 25                        34,433        0.18%          5.230
# 26                        33,481        0.18%          5.086
# 27                        28,723        0.15%          4.363
# 28                        27,870        0.15%          4.233
# 29                        27,283        0.14%          4.144
# 30                        24,603        0.13%          3.737
# 31                        22,287        0.12%          3.385
# 32                             -            -              -

# %% [markdown]
# # Q 5 : Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/ You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used

# %%
# first connect to the driver

driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# connect to  the url that i want to open 

driver.get("https://github.com/")
time.sleep(3)

# %%
#Getting explore button and clicking on it
explore = driver.find_element(By.XPATH ,'//nav[@class="mt-0 px-3 px-lg-0 mb-3 mb-lg-0"]/ul/li[3]').click()

# %%
#Selecting trending option
trend_url = driver.find_element(By.XPATH ,'//nav[@class="mt-0 px-3 px-lg-0 mb-3 mb-lg-0"]/ul/li[3]/div/ul[3]/li[3]/a')
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
#Creating empty list
repo_urls = []
rep_title = []
Description = []
Contributors = []
Language = []
lang = []

# %%
#Fetching urls for each repository
repository = driver.find_elements(By.XPATH ,"//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    repo_urls.append(i.get_attribute("href"))

    
#Scraping data of repository title
title = driver.find_elements(By.XPATH ,"//h1[@class = 'h3 lh-condensed']")
for i in title:
    rep_title.append(i.text)

    
#Scraping data from every repository page
for i in repo_urls:
    driver.get(i)
    time.sleep(3)
    
    
    #Scraping data of decription
    try:
        desc = driver.find_element(By.XPATH ,'//article[@class="markdown-body entry-content container-lg"]/p[2]')
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    #Scraping data of contributors
    try:
        cont_tags = driver.find_element(By.XPATH ,"//*[contains(text(),'    Contributors ')]")
        Contributors.append(cont_tags.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
        
 #fetching Languages used
    try:
        for i in driver.find_elements(By.XPATH ,'//div[@class="Layout-sidebar"]/div/div[6]/div/ul/li/a/span[1]'):
            lang.append(i.text)
        Language.append(lang)
    
    except NoSuchElementException:
        Language.append('-')

# %%
#DATA FRAMEING
Github=pd.DataFrame({})
Github['Repository title'] = rep_title
Github['Repository description'] = Description
Github['Contributors count'] = Contributors
Github['Language used'] = Language

#Printing data frame
Github
# Out:
#                                Repository title  \
# 0                             geohot / tinygrad
# 1                              stashapp / stash
# 2                            refinedev / refine
# 3                        Sanster / lama-cleaner
# 4                            alibaba / havenask
# 5                           SheerSt / pokewilds
# 6                         microsoft / PowerToys
# 7         jwasham / coding-interview-university
# 8                      Bdenneu / CVE-2022-33679
# 9                        sottlmarek / DevSecOps
# 10     rodrigorgtic / nlwcopa-mobile-components
# 11                      prowler-cloud / prowler
# 12                      milanm / DevOps-Roadmap
# 13                            grafana / grafana
# 14                          ssnhd / googlevoice
# 15                      prometheus / prometheus
# 16                          commaai / openpilot
# 17              NationalSecurityAgency / ghidra
# 18  pointfreeco / swift-composable-architecture
# 19                           tiangolo / fastapi
# 20                          Netflix / conductor
# 21        Wechat-ggGitHub / Awesome-GitHub-Repo
# 22                        surrealdb / surrealdb
# 23                                unifyai / ivy
# 24                         danielgindi / Charts
#
#                                Repository description Contributors count  \
# 0                                                                     68
# 1                                                                    117
# 2   refine is headless by design, thereby offering...                102
# 3                                                                      6
# 4   此外，基于Havenask打造的行业AI搜索产品——阿里云OpenSearch，也将持续在阿...                  5
# 5   DISCLAIMER: this is currently in Alpha. Things...                  7
# 6   How to use PowerToys | Downloads & Release not...                316
# 7   This is my multi-month study plan for becoming...                278
# 8                                                                      2
# 9   Note: Currently this is an early version of th...                 30
# 10                                                  -                  -
# 11     Explore the Pro version of Prowler at prowl...                186
# 12                                                                     4
# 13  The open-source platform for monitoring and ob...              1,848
# 14                              您感兴趣的：注册 Google Voice                  -
# 15  Prometheus, a Cloud Native Computing Foundatio...                741
# 16  openpilot is an open source driver assistance ...                364
# 17  Ghidra is a software reverse engineering (SRE)...                206
# 18  The Composable Architecture (TCA, for short) i...                 99
# 19  FastAPI framework, high performance, easy to l...                410
# 20  Conductor is a platform created by Netflix to ...                202
# 21  Awesome GitHub Repo 会收集整理 GitHub 上高质量、有趣的开源项目，...                  -
# 22                                                                    28
# 23  We’re on a mission to unify all ML frameworks ...                526
# 24                                                                   150
#
#                                         Language used
# 0   [Python, Verilog, C, Objective-C++, C++, Shell...
# 1   [Python, Verilog, C, Objective-C++, C++, Shell...
# 2   [Python, Verilog, C, Objective-C++, C++, Shell...
# 3   [Python, Verilog, C, Objective-C++, C++, Shell...
# 4   [Python, Verilog, C, Objective-C++, C++, Shell...
# 5   [Python, Verilog, C, Objective-C++, C++, Shell...
# 6   [Python, Verilog, C, Objective-C++, C++, Shell...
# 7   [Python, Verilog, C, Objective-C++, C++, Shell...
# 8   [Python, Verilog, C, Objective-C++, C++, Shell...
# 9   [Python, Verilog, C, Objective-C++, C++, Shell...
# 10  [Python, Verilog, C, Objective-C++, C++, Shell...
# 11  [Python, Verilog, C, Objective-C++, C++, Shell...
# 12  [Python, Verilog, C, Objective-C++, C++, Shell...
# 13  [Python, Verilog, C, Objective-C++, C++, Shell...
# 14  [Python, Verilog, C, Objective-C++, C++, Shell...
# 15  [Python, Verilog, C, Objective-C++, C++, Shell...
# 16  [Python, Verilog, C, Objective-C++, C++, Shell...
# 17  [Python, Verilog, C, Objective-C++, C++, Shell...
# 18  [Python, Verilog, C, Objective-C++, C++, Shell...
# 19  [Python, Verilog, C, Objective-C++, C++, Shell...
# 20  [Python, Verilog, C, Objective-C++, C++, Shell...
# 21  [Python, Verilog, C, Objective-C++, C++, Shell...
# 22  [Python, Verilog, C, Objective-C++, C++, Shell...
# 23  [Python, Verilog, C, Objective-C++, C++, Shell...
# 24  [Python, Verilog, C, Objective-C++, C++, Shell...

# %% [markdown]
# # Q 8 : Scrape the details of Highest selling novels.
#     Url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/" You have to find the following details:
#         A) Book name
#         B) Author name
#         C) Volumes sold
#         D) Publisher
#         E) Genre

# %%
driver =webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")
driver.maximize_window()

#getting the specified url
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)
time.sleep(3)

#Creating empty list
Book_name = []
Author = []
Volumes_sold = []
Publisher = []
Genre = []

#scraping data of book names
for i in driver.find_elements(By.XPATH ,"//tbody//tr/td[2]"):
    Book_name.append(i.text)

    
#Scraping data of author names
for i in driver.find_elements(By.XPATH ,"//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author.append(i.text)
    except NoSuchElementException:
        Author.append('-')
time.sleep(1)


#Scraping data of volumes sold
for i in driver.find_elements(By.XPATH ,"//tbody/tr/td[4]"):
    Volumes_sold.append(i.text)

    
#Scraping data of publisher names
for i in driver.find_elements(By.XPATH ,"//tbody/tr/td[5]"):
    Publisher.append(i.text)
    
#Scraping data of genre
for i in driver.find_elements(By.XPATH ,"//tbody/tr/td[6]"):
    Genre.append(i.text)

# %%
#DATA FRAMEING
Novel=pd.DataFrame({})
Novel['Book Name'] = Book_name
Novel['Author'] = Author
Novel['Volume sold'] = Volumes_sold
Novel['Publisher'] = Publisher
Novel['Genre'] = Genre

#Printing data frame
Novel
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # Q 9 : Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/ You have to find the following details:
#         A) Name
#
#         B) Year span
#
#         C) Genre
#
#         D) Run time
#
#         E) Ratings
#
#         F) Votes

# %%
driver = webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")
driver.maximize_window()

#getting the specified url
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(3)

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

#Scraping data of Names
for i in driver.find_elements(By.XPATH ,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

    
#Scraping data of Year span
for i in driver.find_elements(By.XPATH ,"//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements(By.XPATH ,"//span[@class='genre']"):
    Genre.append(i.text)

    
#Scraping data of Run time
for i in driver.find_elements(By.XPATH ,"//span[@class='runtime']"):
    Run_time.append(i.text)

    
#Scraping data of Ratings
for i in driver.find_elements(By.XPATH ,"//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
#Scraping data of votes
for i in driver.find_elements(By.XPATH ,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)

# %%
#DATA FRAMEING
IMDB=pd.DataFrame({})
IMDB['Name'] = Name
IMDB['Year Span'] = Year_span
IMDB['Genre'] = Genre
IMDB['Run Time'] = Run_time
IMDB['Ratings'] = Ratings
IMDB['Votes'] = Votes

#Printing data frame
IMDB
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,078,322
# 1    51 min     8.7  1,168,608
# 2    44 min     8.1    979,307
# 3    60 min     7.5    291,517
# 4    43 min     7.6    250,580
# ..      ...     ...        ...
# 95   42 min     7.4     49,967
# 96   50 min     7.8     61,096
# 97   42 min     8.1    196,600
# 98   45 min     7.1     41,422
# 99  572 min     8.6    242,737
#
# [100 rows x 6 columns]

# %% [markdown]
# # Q 10 : Details of Datasets from UCI machine learning repositories.
#
#     Url = https://archive.ics.uci.edu/ You have to find the following details:
#
#             A) Dataset name
#
#             B) Data type
#
#             C) Task
#
#             D) Attribute type
#
#             E) No of instances
#
#             F) No of attribute
#
#             G) Year Note: -
#                 from the home page you have to go to the ShowAllDataset page through cod

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
#Getting the website to driver
driver.get('https://archive.ics.uci.edu/')
driver.maximize_window()

# %%
#Creating empty lists for storing the data
Name=[]
Type=[]
Task=[]
Attribute=[]
No_of_Instance=[]
No_of_Attribute=[]
Year=[]

# %%
#Clicking on view all datasets link
datasets=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
try:
    datasets.click()
except ElementNotInteractableException:
    driver.get(datasets.get_attribute('href'))

# %%
#Scrapping the data having dataset name
try:
    names=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
    
#Scrapping the data having data type
try:
    types=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in types[1:]:
        Type.append(i.text)
except NoSuchElementException:
    Type.append('-')
    
#Scrapping the data having default task
try:
    task=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in task[1:]:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('-')
        
#Scrapping the data having attribute types
try:
    attribute=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in attribute[1:]:
        Attribute.append(i.text)
except NoSuchElementException:
    Attribute.append('-')
    
#Scrapping the data having no of instances
try:
    instance=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in instance[1:]:
        No_of_Instance.append(i.text)
except NoSuchElementException:
    No_of_Instance.append('-')
        
#Scrapping the data having no of attributes
try:
    attribute_no=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in attribute_no[1:]:
        No_of_Attribute.append(i.text)
except NoSuchElementException:
    No_of_Attribute.append('-')
        
#Scrapping the data having the year details
try:
    year=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in year[1:]:
        Year.append(i.text)
except NoSuchElementException:
    Year.append('-')

# %%
#Creating the dataframe
df=pd.DataFrame({"Name":Name,"Data types":Type,"Default Task":Task,"Attribute types":Attribute, 
                 "No of instances":No_of_Instance,"No of atrributes":No_of_Attribute,"Year":Year})
df
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                      Data types          Default Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# 4                 Multivariate        Classification
# ..                          ...                   ...
# 617               Multivariate        Classification
# 618               Multivariate        Classification
# 619                                   Classification
# 620  Multivariate, Time-Series        Classification
# 621                 Univariate            Regression
#
#                  Attribute types No of instances No of atrributes   Year
# 0    Categorical, Integer, Real            4177                8   1995
# 1          Categorical, Integer           48842               14   1996
# 2    Categorical, Integer, Real             798               38
# 3                   Categorical           37711              294   1998
# 4    Categorical, Integer, Real             452              279   1998
# ..                           ...             ...              ...    ...
# 617               Integer, Real           75840              525   2020
# 618               Integer, Real             400               50   2020
# 619                                        1014                7   2020
# 620                        Real           10129               16   2021
# 621                        Real            4000                2   2021
#
# [622 rows x 7 columns]
